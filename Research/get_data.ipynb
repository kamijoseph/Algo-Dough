# %% [markdown]
# ## downloading data from yfinance

# %%
import pandas as pd
import yfinance as yf

# %%
# downloading the data
data = yf.download("MSFT")
# Out:
# Failed to get ticker 'MSFT' reason: Failed to perform, curl: (28) Connection timed out after 30001 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            MSFT        MSFT        MSFT        MSFT       MSFT
# Date
# 2026-07-27  388.368896  393.459320  387.260966  389.347036   27856200
# 2026-07-28  392.610901  399.567805  390.564735  392.421255   32367500
# 2026-07-29  389.806183  400.496050  388.009547  392.660794   47209000
# 2026-07-30  450.252411  457.828146  431.627468  437.077201  110160700
# 2026-07-31  463.846802  465.962813  448.485705  449.154459   60846000
# 2026-08-03  486.733704  490.726188  474.107479  475.235361   66762100
# 2026-08-04  491.884033  498.501581  478.269678  479.996408   50455500
# 2026-08-05  486.544067  497.303811  484.767413  495.427338   33388900
# ...
